# %% [markdown]
# # Exercise 2 — SciPy stats & optimize

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, optimize
rng = np.random.default_rng(1)

# %% [markdown]
# **Task 1.** Sample 1000 points from a `Normal(mean=2, std=1.5)` and fit a Gaussian back to them with `stats.norm.fit`. How close do you get?

# %%
# your code here

# %% [markdown]
# **Task 2.** Plot the histogram of those samples together with the *fitted* PDF.

# %%
# your code here

# %% [markdown]
# **Task 3.** Minimize `f(x) = (x - 3)**2 + sin(x)` starting from `x0 = 0`. Report the argmin and the minimum value.

# %%
# your code here

# %% [markdown]
# **Task 4 (stretch).** Show that starting from `x0 = 10` finds a *different* local minimum — this is why initialization matters.

# %%
# your code here
